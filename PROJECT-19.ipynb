# %% [markdown]
# # Election Dataset

# %%
#importing all the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the dataset
df=pd.read_csv('ElectionData.csv',parse_dates=["time"])
df
# Out:
#        TimeElapsed                time        territoryName  totalMandates  \
# 0                0 2019-10-06 20:10:00  Território Nacional              0
# 1                0 2019-10-06 20:10:00  Território Nacional              0
# 2                0 2019-10-06 20:10:00  Território Nacional              0
# 3                0 2019-10-06 20:10:00  Território Nacional              0
# 4                0 2019-10-06 20:10:00  Território Nacional              0
# ...            ...                 ...                  ...            ...
# 21638          265 2019-10-07 00:35:00                Viseu              8
# 21639          265 2019-10-07 00:35:00                Viseu              8
# 21640          265 2019-10-07 00:35:00                Viseu              8
# 21641          265 2019-10-07 00:35:00                Viseu              8
# 21642          265 2019-10-07 00:35:00                Viseu              8
#
# ...

# %%
#checking the information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21643 entries, 0 to 21642
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   TimeElapsed               21643 non-null  int64
#  1   time                      21643 non-null  datetime64[ns]
#  2   territoryName             21643 non-null  object
#  3   totalMandates             21643 non-null  int64
#  4   availableMandates         21643 non-null  int64
#  5   numParishes               21643 non-null  int64
#  6   numParishesApproved       21643 non-null  int64
#  7   blankVotes                21643 non-null  int64
#  8   blankVotesPercentage      21643 non-null  float64
#  9   nullVotes                 21643 non-null  int64
#  10  nullVotesPercentage       21643 non-null  float64
#  11  votersPercentage          21643 non-null  float64
#  12  subscribedVoters          21643 non-null  int64
# ...

# %% [markdown]
# There are no null values in this dataset

# %%
#checking the 1st  five rows of the dataset
df.head()
# Out:
#    TimeElapsed                time        territoryName  totalMandates  \
# 0            0 2019-10-06 20:10:00  Território Nacional              0
# 1            0 2019-10-06 20:10:00  Território Nacional              0
# 2            0 2019-10-06 20:10:00  Território Nacional              0
# 3            0 2019-10-06 20:10:00  Território Nacional              0
# 4            0 2019-10-06 20:10:00  Território Nacional              0
#
#    availableMandates  numParishes  numParishesApproved  blankVotes  \
# 0                226         3092                 1081        9652
# 1                226         3092                 1081        9652
# 2                226         3092                 1081        9652
# 3                226         3092                 1081        9652
# 4                226         3092                 1081        9652
#
#    blankVotesPercentage  nullVotes  ...  pre.votersPercentage  \
# 0                   2.5       8874  ...                 52.66
# ...

# %%
#checking the shape of dataset
df.shape
# Out:
# (21643, 28)

# %% [markdown]
# There are 21643 rows and 28 columns in this dataset

# %%
#checking all the columns present in this dataset
df.columns
# Out:
# Index(['TimeElapsed', 'time', 'territoryName', 'totalMandates',
#        'availableMandates', 'numParishes', 'numParishesApproved', 'blankVotes',
#        'blankVotesPercentage', 'nullVotes', 'nullVotesPercentage',
#        'votersPercentage', 'subscribedVoters', 'totalVoters', 'pre.blankVotes',
#        'pre.blankVotesPercentage', 'pre.nullVotes', 'pre.nullVotesPercentage',
#        'pre.votersPercentage', 'pre.subscribedVoters', 'pre.totalVoters',
#        'Party', 'Mandates', 'Percentage', 'validVotesPercentage', 'Votes',
#        'Hondt', 'FinalMandates'],
#       dtype='object')

# %%
#checking the data types of these columns
df.dtypes
# Out:
# TimeElapsed                          int64
# time                        datetime64[ns]
# territoryName                       object
# totalMandates                        int64
# availableMandates                    int64
# numParishes                          int64
# numParishesApproved                  int64
# blankVotes                           int64
# blankVotesPercentage               float64
# nullVotes                            int64
# nullVotesPercentage                float64
# votersPercentage                   float64
# subscribedVoters                     int64
# totalVoters                          int64
# pre.blankVotes                       int64
# pre.blankVotesPercentage           float64
# pre.nullVotes                        int64
# pre.nullVotesPercentage            float64
# pre.votersPercentage               float64
# pre.subscribedVoters                 int64
# pre.totalVoters                      int64
# Party                               object
# ...

# %% [markdown]
# There are only two categorical features present in this dataset : 'Territory name' and 'Party' rest are Numerical features except 'time' which is of datetime datatype

# %%
#checking the null values
df.isnull().sum()
# Out:
# TimeElapsed                 0
# time                        0
# territoryName               0
# totalMandates               0
# availableMandates           0
# numParishes                 0
# numParishesApproved         0
# blankVotes                  0
# blankVotesPercentage        0
# nullVotes                   0
# nullVotesPercentage         0
# votersPercentage            0
# subscribedVoters            0
# totalVoters                 0
# pre.blankVotes              0
# pre.blankVotesPercentage    0
# pre.nullVotes               0
# pre.nullVotesPercentage     0
# pre.votersPercentage        0
# pre.subscribedVoters        0
# pre.totalVoters             0
# Party                       0
# Mandates                    0
# Percentage                  0
# validVotesPercentage        0
# Votes                       0
# Hondt                       0
# FinalMandates               0
# dtype: int64

# %%
#checking null values by using heatmap
sns.heatmap(df.isnull())

# %% [markdown]
# There are no null values present in this dataset.

# %%
#checking value counts for territoryName
df['territoryName'].value_counts()
# Out:
# Leiria                 1134
# Porto                  1134
# Braga                  1134
# Território Nacional    1134
# Aveiro                 1080
# Lisboa                 1080
# Coimbra                1080
# Madeira                1080
# Viana do Castelo       1080
# Viseu                  1080
# Setúbal                1080
# Santarém               1026
# Évora                  1026
# Guarda                 1026
# Faro                   1026
# Bragança                972
# Castelo Branco          972
# Portalegre              918
# Beja                    918
# Vila Real               864
# Açores                  799
# Name: territoryName, dtype: int64

# %%
#checking value counts for column Party
df['Party'].value_counts()
# Out:
# CDS-PP       1127
# CH           1127
# PCP-PEV      1127
# L            1127
# IL           1127
# PS           1127
# B.E.         1127
# PCTP/MRPP    1127
# PAN          1127
# A            1127
# PPD/PSD      1127
# PDR          1127
# PNR          1127
# PPM          1073
# R.I.R.       1026
# MPT          1019
# PTP          1019
# NC            972
# PURP          972
# JPP           486
# MAS           425
# Name: Party, dtype: int64

# %%
#Statistical Summary
df.describe()
# Out:
#         TimeElapsed  totalMandates  availableMandates   numParishes  \
# count  21643.000000   21643.000000       21643.000000  21643.000000
# mean     133.146052      11.544795          11.499284    309.956013
# std       77.651193      31.314567          31.738783    659.055911
# min        0.000000       0.000000           0.000000     54.000000
# 25%       65.000000       1.000000           0.000000     75.000000
# 50%      135.000000       4.000000           3.000000    147.000000
# 75%      200.000000       9.000000           9.000000    242.000000
# max      265.000000     226.000000         226.000000   3092.000000
#
#        numParishesApproved     blankVotes  blankVotesPercentage     nullVotes  \
# count         21643.000000   21643.000000          21643.000000  21643.000000
# mean            261.090237    8875.066673              2.621629   6148.068752
# std             583.377428   21484.874088              0.795289  14735.469269
# ...

# %% [markdown]
# There are total 21643 entries
#
# There are outliers present in totalMandates,availableMandates,numParishes,numParishesApproved,blankVotes,Mandates,Percentage,validVotesPercentage,Votes,Hondt,FinalMandates

# %%
#Checking the correlation between the columns
df.corr()
# Out:
#                           TimeElapsed  totalMandates  availableMandates  \
# TimeElapsed                  1.000000       0.260377          -0.261627
# totalMandates                0.260377       1.000000           0.217404
# availableMandates           -0.261627       0.217404           1.000000
# numParishes                 -0.001944       0.765877           0.745472
# numParishesApproved          0.100432       0.873415           0.562719
# blankVotes                   0.192350       0.969988           0.390638
# blankVotesPercentage         0.034343      -0.003149          -0.002806
# nullVotes                    0.185784       0.967294           0.407366
# nullVotesPercentage         -0.225021      -0.165132           0.029915
# votersPercentage             0.029698       0.171317           0.112293
# subscribedVoters             0.195487       0.974407           0.385828
# totalVoters                  0.198243       0.976336           0.379093
# ...

# %%
#checking correlation via visualization (heatmap)
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True,fmt='.0%',cmap='BuPu')
plt.show()

# %%
plt.figure(figsize=(20,10))
df.drop('FinalMandates',axis=1).corrwith(df['FinalMandates']).plot(kind='bar',grid=True)
plt.xticks(rotation=20)
plt.title("Correlation with target variable")
# Out:
# Text(0.5, 1.0, 'Correlation with target variable')

# %% [markdown]
# Almost all attributes are positively correlated.
#
# nullvotespercentage and prenullvotespercentage are the negatively correlated column with target variable
#
# Hondt and Votes are highly correlated columns with target variable

# %%
#Checking the count of territoryName
plt.figure(figsize=(20,10))
sns.countplot(x='territoryName',data=df)
plt.show()

# %% [markdown]
# Territorio,Braga,Leiria,Porto have maximum count whereas Acores has least.

# %%
#Checking the count of territoryName
plt.figure(figsize=(20,10))
sns.countplot(x='Party',data=df)
plt.show()

# %% [markdown]
# Almost all parties have same count except R.I.R ,JPP,MAS that have comparatively less count.

# %%
#Checking the count of territoryName
plt.figure(figsize=(20,10))
sns.countplot(x='numParishes',data=df)
plt.show()

# %% [markdown]
# 69 has maximum count and 156 has least.

# %%
#Checking the count of territoryName
plt.figure(figsize=(20,10))
sns.barplot(x='numParishes',y='FinalMandates',data=df)
plt.show()

# %% [markdown]
# 3092 has maximum Final Mandates than all other numParishes

# %%
#Encoding the attributes
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder() 
list1=['time','territoryName','Party']
for val in list1:
    df[val]=le.fit_transform(df[val].astype(str))

# %%
df
# Out:
#        TimeElapsed  time  territoryName  totalMandates  availableMandates  \
# 0                0     0             16              0                226
# 1                0     0             16              0                226
# 2                0     0             16              0                226
# 3                0     0             16              0                226
# 4                0     0             16              0                226
# ...            ...   ...            ...            ...                ...
# 21638          265    53             19              8                  0
# 21639          265    53             19              8                  0
# 21640          265    53             19              8                  0
# 21641          265    53             19              8                  0
# 21642          265    53             19              8                  0
#
#        numParishes  numParishesApproved  blankVotes  blankVotesPercentage  \
# ...

# %% [markdown]
# 'time','territoryName','Party' have been changed to numerical types

# %% [markdown]
# # Plotting the outliers

# %%
df.plot(kind='box',subplots=True,layout=(4,7))
# Out:
# TimeElapsed                     AxesSubplot(0.125,0.71587;0.0945122x0.16413)
# time                         AxesSubplot(0.238415,0.71587;0.0945122x0.16413)
# territoryName                AxesSubplot(0.351829,0.71587;0.0945122x0.16413)
# totalMandates                AxesSubplot(0.465244,0.71587;0.0945122x0.16413)
# availableMandates            AxesSubplot(0.578659,0.71587;0.0945122x0.16413)
# numParishes                  AxesSubplot(0.692073,0.71587;0.0945122x0.16413)
# numParishesApproved          AxesSubplot(0.805488,0.71587;0.0945122x0.16413)
# blankVotes                     AxesSubplot(0.125,0.518913;0.0945122x0.16413)
# blankVotesPercentage        AxesSubplot(0.238415,0.518913;0.0945122x0.16413)
# nullVotes                   AxesSubplot(0.351829,0.518913;0.0945122x0.16413)
# nullVotesPercentage         AxesSubplot(0.465244,0.518913;0.0945122x0.16413)
# votersPercentage            AxesSubplot(0.578659,0.518913;0.0945122x0.16413)
# ...

# %% [markdown]
# There are outliers in many columns

# %%
#Detecting outliers
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[ 1.71470808,  1.71470808,  0.98296816, ...,  1.4192844 ,
#         14.75732693, 15.25996213],
#        [ 1.71470808,  1.71470808,  0.98296816, ...,  1.211248  ,
#         12.69167309, 11.04023671],
#        [ 1.71470808,  1.71470808,  0.98296816, ...,  0.11229293,
#          2.36340389,  2.60078588],
#        ...,
#        [ 1.69806785,  1.69806785,  1.48421407, ...,  0.16751275,
#          0.17893929,  0.1638618 ],
#        [ 1.69806785,  1.69806785,  1.48421407, ...,  0.16769534,
#          0.17893929,  0.1638618 ],
#        [ 1.69806785,  1.69806785,  1.48421407, ...,  0.16899497,
#          0.17893929,  0.1638618 ]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([    0,     0,     0, ..., 21608, 21623, 21623], dtype=int64), array([ 4,  5, 23, ..., 24, 23, 24], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)] #removing the outliers
df_new
# Out:
#        TimeElapsed  time  territoryName  totalMandates  availableMandates  \
# 22               0     0              0              0                 16
# 23               0     0              0              0                 16
# 24               0     0              0              0                 16
# 25               0     0              0              0                 16
# 26               0     0              0              0                 16
# ...            ...   ...            ...            ...                ...
# 21638          265    53             19              8                  0
# 21639          265    53             19              8                  0
# 21640          265    53             19              8                  0
# 21641          265    53             19              8                  0
# 21642          265    53             19              8                  0
#
#        numParishes  numParishesApproved  blankVotes  blankVotesPercentage  \
# ...

# %%
df.shape
# Out:
# (21643, 28)

# %%
df_new.shape
# Out:
# (18333, 28)

# %% [markdown]
# 3310 rows are removed

# %%
df=df_new

# %%
#checking skewness
df.skew()
# Out:
# TimeElapsed                -0.024110
# time                       -0.024110
# territoryName               0.034073
# totalMandates               2.542453
# availableMandates           2.593527
# numParishes                 0.585363
# numParishesApproved         0.619329
# blankVotes                  1.800122
# blankVotesPercentage       -0.844508
# nullVotes                   2.103352
# nullVotesPercentage         0.564426
# votersPercentage           -0.392023
# subscribedVoters            2.407541
# totalVoters                 2.468630
# pre.blankVotes              2.034860
# pre.blankVotesPercentage   -0.410446
# pre.nullVotes               2.340000
# pre.nullVotesPercentage     1.033803
# pre.votersPercentage       -0.514215
# pre.subscribedVoters        2.370988
# pre.totalVoters             2.468950
# Party                       0.009657
# Mandates                    7.177093
# Percentage                  3.373567
# validVotesPercentage        3.383145
# ...

# %%
#Treating skewness via log method
for col in df.columns:
    if df.skew().loc[col]>0.55:
        df[col]=np.log1p(df[col])
# Out:
# <ipython-input-34-daa4fbe8e966>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col]=np.log1p(df[col])

# %%
#Again checking the skewness
df.skew()
# Out:
# TimeElapsed                -0.024110
# time                       -0.024110
# territoryName               0.034073
# totalMandates               0.020702
# availableMandates           0.503375
# numParishes                -0.138265
# numParishesApproved        -1.099103
# blankVotes                 -0.592756
# blankVotesPercentage       -0.844508
# nullVotes                  -0.880145
# nullVotesPercentage         0.329675
# votersPercentage           -0.392023
# subscribedVoters           -0.772107
# totalVoters                -0.647681
# pre.blankVotes             -0.642916
# pre.blankVotesPercentage   -0.410446
# pre.nullVotes              -0.937998
# pre.nullVotesPercentage     0.628444
# pre.votersPercentage       -0.514215
# pre.subscribedVoters       -0.802802
# pre.totalVoters            -0.670218
# Party                       0.009657
# Mandates                    4.479200
# Percentage                  1.565493
# validVotesPercentage        1.550088
# ...

# %% [markdown]
# # Model Training

# %%
#Splitting data into input and output variable
x=df.drop(['FinalMandates'],axis=1)
x.head()
# Out:
#     TimeElapsed  time  territoryName  totalMandates  availableMandates  \
# 22            0     0              0            0.0           2.833213
# 23            0     0              0            0.0           2.833213
# 24            0     0              0            0.0           2.833213
# 25            0     0              0            0.0           2.833213
# 26            0     0              0            0.0           2.833213
#
#     numParishes  numParishesApproved  blankVotes  blankVotesPercentage  \
# 22     4.997212             2.564949    5.231109                  2.92
# 23     4.997212             2.564949    5.231109                  2.92
# 24     4.997212             2.564949    5.231109                  2.92
# 25     4.997212             2.564949    5.231109                  2.92
# 26     4.997212             2.564949    5.231109                  2.92
#
#     nullVotes  ...  pre.nullVotesPercentage  pre.votersPercentage  \
# ...

# %%
#scaling the input data
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)

# %%
x=pd.DataFrame(x)

# %%
x.columns=['TimeElapsed', 'time', 'territoryName', 'totalMandates',
       'availableMandates', 'numParishes', 'numParishesApproved', 'blankVotes',
       'blankVotesPercentage', 'nullVotes', 'nullVotesPercentage',
       'votersPercentage', 'subscribedVoters', 'totalVoters', 'pre.blankVotes',
       'pre.blankVotesPercentage', 'pre.nullVotes', 'pre.nullVotesPercentage',
       'pre.votersPercentage', 'pre.subscribedVoters', 'pre.totalVoters',
       'Party', 'Mandates', 'Percentage', 'validVotesPercentage', 'Votes',
       'Hondt']

# %%
x.head()
# Out:
#    TimeElapsed      time  territoryName  totalMandates  availableMandates  \
# 0    -1.752045 -1.752045      -1.741356      -1.454853           1.362509
# 1    -1.752045 -1.752045      -1.741356      -1.454853           1.362509
# 2    -1.752045 -1.752045      -1.741356      -1.454853           1.362509
# 3    -1.752045 -1.752045      -1.741356      -1.454853           1.362509
# 4    -1.752045 -1.752045      -1.741356      -1.454853           1.362509
#
#    numParishes  numParishesApproved  blankVotes  blankVotesPercentage  \
# 0     0.168399            -2.386279   -1.995387              0.540356
# 1     0.168399            -2.386279   -1.995387              0.540356
# 2     0.168399            -2.386279   -1.995387              0.540356
# 3     0.168399            -2.386279   -1.995387              0.540356
# 4     0.168399            -2.386279   -1.995387              0.540356
#
#    nullVotes  ...  pre.nullVotesPercentage  pre.votersPercentage  \
# ...

# %%
#target column
y=df['FinalMandates'].values
y
# Out:
# array([2.07944154, 1.09861229, 0.69314718, ..., 0.        , 0.        ,
#        0.        ])

# %%
#Checking the shape of input and output variable
x.shape
# Out:
# (18333, 27)

# %%
y.shape
# Out:
# (18333,)

# %%
#Importing all the libraries,metrices required for ML 
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score

import warnings
warnings.filterwarnings('ignore')

# %%
#splitting the data into training and testing
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)

# %%
#checking the shape of training and testing data
print(x_train.shape,x_test.shape)
# Out:
# (14666, 27) (3667, 27)

# %%
#checking the shape of training and testing data
print(y_train.shape,y_test.shape)
# Out:
# (14666,) (3667,)

# %%
#All algorithms using loop
model=[LinearRegression(),Lasso(),Ridge(),ElasticNet(),SVR(),DecisionTreeRegressor(),KNeighborsRegressor(),RandomForestRegressor(),AdaBoostRegressor(), GradientBoostingRegressor()]

for m in model:
    m.fit(x_train,y_train)
    Score=m.score(x_train,y_train)
    predm=m.predict(x_test)
    print('Score of',m,'is:',Score)
    print('Mean Absolute Error:',mean_absolute_error(y_test,predm))
    print('Mean Squared Error:',mean_squared_error(y_test,predm))
    print('RMSE:',np.sqrt(mean_squared_error(y_test,predm)))
    print('r2_score:',r2_score(y_test,predm))
    print('****************************************')
    print('\n')
# Out:
# Score of LinearRegression() is: 0.9793895006452246
# Mean Absolute Error: 0.018304240368661684
# Mean Squared Error: 0.004137111542428269
# RMSE: 0.06432038201401068
# r2_score: 0.97723294941198
# ****************************************
#
#
# Score of Lasso() is: 0.0
# Mean Absolute Error: 0.24991819815773986
# Mean Squared Error: 0.18174600686739276
# RMSE: 0.4263167916789025
# r2_score: -0.0001713732117221145
# ****************************************
#
#
# Score of Ridge() is: 0.9793327640509428
# Mean Absolute Error: 0.017885259642581842
# Mean Squared Error: 0.0041410284721505935
# RMSE: 0.06435082339916556
# r2_score: 0.9772113940499302
# ****************************************
#
#
# Score of ElasticNet() is: 0.0
# Mean Absolute Error: 0.24991819815773986
# Mean Squared Error: 0.18174600686739276
# RMSE: 0.4263167916789025
# r2_score: -0.0001713732117221145
# ****************************************
#
#
# Score of SVR() is: 0.9780241172289561
# ...

# %% [markdown]
# All models are working well out of which DecisionTreeRegressor is giving best score and r2_score.

# %%
dt=DecisionTreeRegressor()
dt.fit(x_train,y_train)
Sc=dt.score(x_train,y_train)
pred=dt.predict(x_test)
print('Score of',dt,'is:',Sc)
# Out:
# Score of DecisionTreeRegressor() is: 1.0

# %%
#checking cross_val_score for DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
print("Mean r2_score for DecisionTreeRegressor:",cross_val_score(dt,x,y,cv=10,scoring="r2").mean())
print("Standard deviation in r2_score for DecisionTreeRegressor:",cross_val_score(dt,x,y,cv=10,scoring="r2").std())
# Out:
# Mean r2_score for DecisionTreeRegressor: 0.9974831939650368
# Standard deviation in r2_score for DecisionTreeRegressor: 0.005182053156069926

# %% [markdown]
# So DecisionTreeRegressor is working well and its neither underfitting/overfitting so we can choose it as our final model.

# %%
#Saving the best model
import joblib
joblib.dump(dt,'Election_Dataset.obj')
# Out:
# ['Election_Dataset.obj']
